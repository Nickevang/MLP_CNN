# %% [markdown]
# The following additional libraries are needed to run this
# notebook. Note that running on Colab is experimental, please report a Github
# issue if you have any problem.

# %%
# !pip install d2l==1.0.3
# Out:
# Collecting d2l==1.0.3
#   Downloading d2l-1.0.3-py3-none-any.whl.metadata (556 bytes)
# Collecting jupyter==1.0.0 (from d2l==1.0.3)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting numpy==1.23.5 (from d2l==1.0.3)
#   Downloading numpy-1.23.5-cp311-cp311-win_amd64.whl (14.6 MB)
#      ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#      ---------------------------------------- 0.1/14.6 MB 2.2 MB/s eta 0:00:07
#       --------------------------------------- 0.3/14.6 MB 3.5 MB/s eta 0:00:05
#      - -------------------------------------- 0.6/14.6 MB 4.4 MB/s eta 0:00:04
#      -- ------------------------------------- 0.9/14.6 MB 4.8 MB/s eta 0:00:03
#      --- ------------------------------------ 1.2/14.6 MB 5.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.5/14.6 MB 5.3 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.8/14.6 MB 5.5 MB/s eta 0:00:03
#      ----- ---------------------------------- 2.1/14.6 MB 5.6 MB/s eta 0:00:03
#      ------ --------------------------------- 2.4/14.6 MB 5.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.7/14.6 MB 5.9 MB/s eta 0:00:03
#      -------- ------------------------------- 3.0/14.6 MB 6.0 MB/s eta 0:00:02
#      -------- ------------------------------- 3.3/14.6 MB 6.0 MB/s eta 0:00:02
#      --------- ------------------------------ 3.6/14.6 MB 6.0 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.9/14.6 MB 6.0 MB/s eta 0:00:02
#      ----------- ---------------------------- 4.2/14.6 MB 6.0 MB/s eta 0:00:02
#      ------------ --------------------------- 4.5/14.6 MB 6.1 MB/s eta 0:00:02
#      ------------- -------------------------- 4.8/14.6 MB 6.1 MB/s eta 0:00:02
#      ------------- -------------------------- 5.1/14.6 MB 6.1 MB/s eta 0:00:02
#      -------------- ------------------------- 5.4/14.6 MB 6.1 MB/s eta 0:00:02
#      --------------- ------------------------ 5.7/14.6 MB 6.1 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.9/14.6 MB 6.1 MB/s eta 0:00:02
#      ----------------- ---------------------- 6.2/14.6 MB 6.1 MB/s eta 0:00:02
#      ----------------- ---------------------- 6.5/14.6 MB 6.1 MB/s eta 0:00:02
#      ------------------ --------------------- 6.8/14.6 MB 6.2 MB/s eta 0:00:02
#      ------------------- -------------------- 7.1/14.6 MB 6.2 MB/s eta 0:00:02
#      -------------------- ------------------- 7.4/14.6 MB 6.1 MB/s eta 0:00:02
#      --------------------- ------------------ 7.7/14.6 MB 6.2 MB/s eta 0:00:02
#      --------------------- ------------------ 8.0/14.6 MB 6.2 MB/s eta 0:00:02
#      ---------------------- ----------------- 8.3/14.6 MB 6.2 MB/s eta 0:00:02
#      ----------------------- ---------------- 8.6/14.6 MB 6.2 MB/s eta 0:00:01
#      ------------------------ --------------- 8.9/14.6 MB 6.2 MB/s eta 0:00:01
#      ------------------------- -------------- 9.2/14.6 MB 6.2 MB/s eta 0:00:01
#      ------------------------- -------------- 9.5/14.6 MB 6.3 MB/s eta 0:00:01
#      -------------------------- ------------- 9.8/14.6 MB 6.3 MB/s eta 0:00:01
#      --------------------------- ------------ 10.1/14.6 MB 6.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 10.4/14.6 MB 6.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 10.7/14.6 MB 6.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 11.0/14.6 MB 6.4 MB/s eta 0:00:01
#      ------------------------------ --------- 11.2/14.6 MB 6.4 MB/s eta 0:00:01
#      ------------------------------- -------- 11.6/14.6 MB 6.4 MB/s eta 0:00:01
#      -------------------------------- ------- 11.8/14.6 MB 6.4 MB/s eta 0:00:01
#      --------------------------------- ------ 12.1/14.6 MB 6.4 MB/s eta 0:00:01
#      --------------------------------- ------ 12.4/14.6 MB 6.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 12.7/14.6 MB 6.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 13.0/14.6 MB 6.4 MB/s eta 0:00:01
#      ------------------------------------ --- 13.3/14.6 MB 6.4 MB/s eta 0:00:01
#      ------------------------------------- -- 13.6/14.6 MB 6.4 MB/s eta 0:00:01
#      ------------------------------------- -- 13.9/14.6 MB 6.4 MB/s eta 0:00:01
#      -------------------------------------- - 14.2/14.6 MB 6.4 MB/s eta 0:00:01
#      ---------------------------------------  14.5/14.6 MB 6.4 MB/s eta 0:00:01
#      ---------------------------------------  14.6/14.6 MB 6.4 MB/s eta 0:00:01
#      ---------------------------------------- 14.6/14.6 MB 6.3 MB/s eta 0:00:00
# Collecting matplotlib==3.7.2 (from d2l==1.0.3)
#   Downloading matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from d2l==1.0.3) (0.1.6)
# Requirement already satisfied: requests==2.31.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from d2l==1.0.3) (2.31.0)
# Collecting pandas==2.0.3 (from d2l==1.0.3)
#   Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Collecting scipy==1.10.1 (from d2l==1.0.3)
#   Downloading scipy-1.10.1-cp311-cp311-win_amd64.whl (42.2 MB)
#      ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#      ---------------------------------------- 0.3/42.2 MB 7.9 MB/s eta 0:00:06
#       --------------------------------------- 0.5/42.2 MB 6.7 MB/s eta 0:00:07
#       --------------------------------------- 0.8/42.2 MB 6.6 MB/s eta 0:00:07
#      - -------------------------------------- 1.1/42.2 MB 6.5 MB/s eta 0:00:07
#      - -------------------------------------- 1.4/42.2 MB 6.4 MB/s eta 0:00:07
#      - -------------------------------------- 1.7/42.2 MB 6.4 MB/s eta 0:00:07
#      - -------------------------------------- 2.0/42.2 MB 6.4 MB/s eta 0:00:07
#      -- ------------------------------------- 2.3/42.2 MB 6.6 MB/s eta 0:00:07
#      -- ------------------------------------- 2.6/42.2 MB 6.5 MB/s eta 0:00:07
#      -- ------------------------------------- 2.9/42.2 MB 6.6 MB/s eta 0:00:06
#      -- ------------------------------------- 3.2/42.2 MB 6.5 MB/s eta 0:00:06
#      --- ------------------------------------ 3.2/42.2 MB 6.3 MB/s eta 0:00:07
#      --- ------------------------------------ 3.2/42.2 MB 6.1 MB/s eta 0:00:07
#      --- ------------------------------------ 3.2/42.2 MB 6.1 MB/s eta 0:00:07
#      --- ------------------------------------ 3.3/42.2 MB 4.8 MB/s eta 0:00:09
#      --- ------------------------------------ 3.3/42.2 MB 4.8 MB/s eta 0:00:09
#      --- ------------------------------------ 3.3/42.2 MB 4.4 MB/s eta 0:00:09
#      --- ------------------------------------ 3.3/42.2 MB 4.4 MB/s eta 0:00:09
#      --- ------------------------------------ 3.4/42.2 MB 4.1 MB/s eta 0:00:10
#      --- ------------------------------------ 3.4/42.2 MB 4.1 MB/s eta 0:00:10
#      --- ------------------------------------ 3.4/42.2 MB 3.6 MB/s eta 0:00:11
#      --- ------------------------------------ 3.7/42.2 MB 3.9 MB/s eta 0:00:10
#      --- ------------------------------------ 3.7/42.2 MB 3.9 MB/s eta 0:00:10
1-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter==1.0.0->d2l==1.0.3)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: nbconvert in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter==1.0.0->d2l==1.0.3) (7.11.0)
# Requirement already satisfied: ipykernel in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter==1.0.0->d2l==1.0.3) (6.26.0)
# Collecting ipywidgets (from jupyter==1.0.0->d2l==1.0.3)
#   Downloading ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (10.1.0)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib==3.7.2->d2l==1.0.3)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 0.0/98.3 kB ? eta -:--:--
#      ---------------------------------------- 98.3/98.3 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (2.8.2)
# Requirement already satisfied: traitlets in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from matplotlib-inline==0.1.6->d2l==1.0.3) (5.13.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.0.3->d2l==1.0.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.0.3->d2l==1.0.3) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from requests==2.31.0->d2l==1.0.3) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from requests==2.31.0->d2l==1.0.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from requests==2.31.0->d2l==1.0.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from requests==2.31.0->d2l==1.0.3) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.7.2->d2l==1.0.3) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (8.17.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (5.5.0)
# Requirement already satisfied: nest-asyncio in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (1.5.8)
# Requirement already satisfied: psutil in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (5.9.6)
# Requirement already satisfied: pyzmq>=20 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (6.3.3)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets->jupyter==1.0.0->d2l==1.0.3)
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets->jupyter==1.0.0->d2l==1.0.3)
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-console->jupyter==1.0.0->d2l==1.0.3) (3.0.41)
# Requirement already satisfied: pygments in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-console->jupyter==1.0.0->d2l==1.0.3) (2.17.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from notebook->jupyter==1.0.0->d2l==1.0.3) (2.10.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from notebook->jupyter==1.0.0->d2l==1.0.3) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from notebook->jupyter==1.0.0->d2l==1.0.3) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from notebook->jupyter==1.0.0->d2l==1.0.3) (0.2.3)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter==1.0.0->d2l==1.0.3)
#   Downloading QtPy-2.4.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: webencodings in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0->d2l==1.0.3) (0.5.1)
# Requirement already satisfied: decorator in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.6.3)
# Requirement already satisfied: colorama in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l==1.0.3) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l==1.0.3) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (4.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.4.4)
# Requirement already satisfied: overrides in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.18.0)
# Requirement already satisfied: pywinpty in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (2.0.12)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.18.0)
# Requirement already satisfied: websocket-client in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter==1.0.0->d2l==1.0.3) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter==1.0.0->d2l==1.0.3) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (4.20.0)
# Requirement already satisfied: fastjsonschema in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->d2l==1.0.3) (2.19.0)
# Requirement already satisfied: wcwidth in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->d2l==1.0.3) (0.2.10)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l==1.0.3) (2.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (0.13.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.1.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (2.4)
# Requirement already satisfied: uri-template in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\nicka\appdata\local\programs\python\python311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (2.8.19.14)
# Downloading d2l-1.0.3-py3-none-any.whl (111 kB)
#    ---------------------------------------- 0.0/111.7 kB ? eta -:--:--
#    ---------------------------------------- 111.7/111.7 kB 6.8 MB/s eta 0:00:00
# Downloading matplotlib-3.7.2-cp311-cp311-win_amd64.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB 6.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/7.5 MB 6.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.5 MB 6.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/7.5 MB 6.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.5 MB 6.1 MB/s eta 0:00:02
#    --------- ------------------------------ 1.7/7.5 MB 6.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.0/7.5 MB 6.2 MB/s eta 0:00:01
#    ------------ --------------------------- 2.3/7.5 MB 6.2 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/7.5 MB 6.2 MB/s eta 0:00:01
#    --------------- ------------------------ 2.9/7.5 MB 6.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.2/7.5 MB 6.2 MB/s eta 0:00:01
#    ------------------ --------------------- 3.5/7.5 MB 6.4 MB/s eta 0:00:01
#    -------------------- ------------------- 3.8/7.5 MB 6.4 MB/s eta 0:00:01
#    --------------------- ------------------ 4.1/7.5 MB 6.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.4/7.5 MB 6.4 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.5 MB 6.4 MB/s eta 0:00:01
#    -------------------------- ------------- 5.0/7.5 MB 6.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.3/7.5 MB 6.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.6/7.5 MB 6.4 MB/s eta 0:00:01
#    ------------------------------- -------- 5.9/7.5 MB 6.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.2/7.5 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.5/7.5 MB 6.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.7/7.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.0/7.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  7.3/7.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 6.3 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.6 MB 5.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/10.6 MB 5.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/10.6 MB 6.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/10.6 MB 6.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/10.6 MB 6.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.7/10.6 MB 6.5 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/10.6 MB 6.5 MB/s eta 0:00:02
#    -------- ------------------------------- 2.3/10.6 MB 6.5 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/10.6 MB 6.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.6 MB 6.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.2/10.6 MB 6.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.5/10.6 MB 6.4 MB/s eta 0:00:02
#    -------------- ------------------------- 3.8/10.6 MB 6.4 MB/s eta 0:00:02
#    --------------- ------------------------ 4.1/10.6 MB 6.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.4/10.6 MB 6.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/10.6 MB 6.3 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/10.6 MB 6.4 MB/s eta 0:00:01
#    ------------------- -------------------- 5.3/10.6 MB 6.4 MB/s eta 0:00:01
#    -------------------- ------------------- 5.6/10.6 MB 6.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.8/10.6 MB 6.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.1/10.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.4/10.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------- -------------- 6.7/10.6 MB 6.4 MB/s eta 0:00:01
#    -------------------------- ------------- 7.0/10.6 MB 6.4 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.6 MB 6.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.6 MB 6.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------------ --------- 8.2/10.6 MB 6.4 MB/s eta 0:00:01
#    -------------------------------- ------- 8.5/10.6 MB 6.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.8/10.6 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.1/10.6 MB 6.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.6 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 6.4 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 8.1 MB/s eta 0:00:00
# Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
#    ---------------------------------------- 0.0/123.4 kB ? eta -:--:--
#    ---------------------------------------- 123.4/123.4 kB 7.5 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#    ---------------------------------------- 0.0/214.9 kB ? eta -:--:--
#    ---------------------------------------- 214.9/214.9 kB 6.4 MB/s eta 0:00:00
# Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.5 kB ? eta -:--:--
#    ---------------------------------------- 93.5/93.5 kB 5.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.3 MB 9.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.6/2.3 MB 7.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.9/2.3 MB 7.0 MB/s eta 0:00:01
#    -------------------- ------------------- 1.2/2.3 MB 6.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.5/2.3 MB 6.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, qtpy, pyparsing, numpy, jupyterlab-widgets, scipy, pandas, matplotlib, ipywidgets, qtconsole, jupyter-console, jupyter, d2l
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.1
#     Uninstalling numpy-1.26.1:
#       Successfully uninstalled numpy-1.26.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.3
#     Uninstalling scipy-1.11.3:
#       Successfully uninstalled scipy-1.11.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.3
#     Uninstalling pandas-2.1.3:
#       Successfully uninstalled pandas-2.1.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.2
#     Uninstalling matplotlib-3.8.2:
#       Successfully uninstalled matplotlib-3.8.2
# Successfully installed d2l-1.0.3 ipywidgets-8.1.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyterlab-widgets-3.0.9 matplotlib-3.7.2 numpy-1.23.5 pandas-2.0.3 pyparsing-3.0.9 qtconsole-5.5.1 qtpy-2.4.1 scipy-1.10.1 widgetsnbextension-4.0.9

# %%
import collections
import math
import os
import shutil
import pandas as pd
import torch
import torchvision
from torch import nn
from d2l import torch as d2l

# %%
#@save
d2l.DATA_HUB['cifar10_tiny'] = (d2l.DATA_URL + 'kaggle_cifar10_tiny.zip',
                                '2068874e4b9a9f0fb07ebe0ad2b29754449ccacd')

# If you use the full dataset downloaded for the Kaggle competition, set
# `demo` to False
demo = True

if demo:
    data_dir = d2l.download_extract('cifar10_tiny')
else:
    data_dir = '../data/cifar-10/'
# Out:
# Downloading ../data\kaggle_cifar10_tiny.zip from http://d2l-data.s3-accelerate.amazonaws.com/kaggle_cifar10_tiny.zip...

# %% [markdown]
# ### [**Organizing the Dataset**]
#
# We need to organize datasets to facilitate model training and testing.
# Let's first read the labels from the csv file.
# The following function returns a dictionary that maps
# the non-extension part of the filename to its label.

# %%
#@save
def read_csv_labels(fname):
    """Read `fname` to return a filename to label dictionary."""
    with open(fname, 'r') as f:
        # Skip the file header line (column name)
        lines = f.readlines()[1:]
    tokens = [l.rstrip().split(',') for l in lines]
    return dict(((name, label) for name, label in tokens))

labels = read_csv_labels(os.path.join(data_dir, 'trainLabels.csv'))
print('# training examples:', len(labels))
print('# classes:', len(set(labels.values())))
# Out:
# # training examples: 1000
# # classes: 10

# %% [markdown]
# Next, we define the `reorg_train_valid` function to [**split the validation set out of the original training set.**]
# The argument `valid_ratio` in this function is the ratio of the number of examples in the validation set to the number of examples in the original training set.
# More concretely,
# let $n$ be the number of images of the class with the least examples, and $r$ be the ratio.
# The validation set will split out
# $\max(\lfloor nr\rfloor,1)$ images for each class.
# Let's use `valid_ratio=0.1` as an example. Since the original training set has 50000 images,
# there will be 45000 images used for training in the path `train_valid_test/train`,
# while the other 5000 images will be split out
# as validation set in the path `train_valid_test/valid`. After organizing the dataset, images of the same class will be placed under the same folder.

# %%
#@save
def copyfile(filename, target_dir):
    """Copy a file into a target directory."""
    os.makedirs(target_dir, exist_ok=True)
    shutil.copy(filename, target_dir)

#@save
def reorg_train_valid(data_dir, labels, valid_ratio):
    """Split the validation set out of the original training set."""
    # The number of examples of the class that has the fewest examples in the
    # training dataset
    n = collections.Counter(labels.values()).most_common()[-1][1]
    # The number of examples per class for the validation set
    n_valid_per_label = max(1, math.floor(n * valid_ratio))
    label_count = {}
    for train_file in os.listdir(os.path.join(data_dir, 'train')):
        label = labels[train_file.split('.')[0]]
        fname = os.path.join(data_dir, 'train', train_file)
        copyfile(fname, os.path.join(data_dir, 'train_valid_test',
                                     'train_valid', label))
        if label not in label_count or label_count[label] < n_valid_per_label:
            copyfile(fname, os.path.join(data_dir, 'train_valid_test',
                                         'valid', label))
            label_count[label] = label_count.get(label, 0) + 1
        else:
            copyfile(fname, os.path.join(data_dir, 'train_valid_test',
                                         'train', label))
    return n_valid_per_label

# %% [markdown]
# The `reorg_test` function below [**organizes the testing set for data loading during prediction.**]

# %%
#@save
def reorg_test(data_dir):
    """Organize the testing set for data loading during prediction."""
    for test_file in os.listdir(os.path.join(data_dir, 'test')):
        copyfile(os.path.join(data_dir, 'test', test_file),
                 os.path.join(data_dir, 'train_valid_test', 'test',
                              'unknown'))

# %% [markdown]
# Finally, we use a function to [**invoke**]
# the `read_csv_labels`, `reorg_train_valid`, and `reorg_test` (**functions defined above.**)

# %%
def reorg_cifar10_data(data_dir, valid_ratio):
    labels = read_csv_labels(os.path.join(data_dir, 'trainLabels.csv'))
    reorg_train_valid(data_dir, labels, valid_ratio)
    reorg_test(data_dir)

# %% [markdown]
# Here we only set the batch size to 32 for the small-scale sample of the dataset.
# When training and testing
# the complete dataset of the Kaggle competition,
# `batch_size` should be set to a larger integer, such as 128.
# We split out 10% of the training examples as the validation set for tuning hyperparameters.

# %%
batch_size = 32 if demo else 128
valid_ratio = 0.1
reorg_cifar10_data(data_dir, valid_ratio)

# %% [markdown]
# ## [**Image Augmentation**]
#
# We use image augmentation to address overfitting.
# For example, images can be flipped horizontally at random during training.
# We can also perform standardization for the three RGB channels of color images. Below lists some of these operations that you can tweak.

# %%
transform_train = torchvision.transforms.Compose([
    # Scale the image up to a square of 40 pixels in both height and width
    torchvision.transforms.Resize(40),
    # Randomly crop a square image of 40 pixels in both height and width to
    # produce a small square of 0.64 to 1 times the area of the original
    # image, and then scale it to a square of 32 pixels in both height and
    # width
    torchvision.transforms.RandomResizedCrop(32, scale=(0.64, 1.0),
                                                   ratio=(1.0, 1.0)),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.ToTensor(),
    # Standardize each channel of the image
    torchvision.transforms.Normalize([0.4914, 0.4822, 0.4465],
                                     [0.2023, 0.1994, 0.2010])])

# %% [markdown]
# During testing,
# we only perform standardization on images
# so as to
# remove randomness in the evaluation results.

# %%
transform_test = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize([0.4914, 0.4822, 0.4465],
                                     [0.2023, 0.1994, 0.2010])])

# %% [markdown]
# ## Reading the Dataset
#
# Next, we [**read the organized dataset consisting of raw image files**]. Each example includes an image and a label.

# %%
train_ds, train_valid_ds = [torchvision.datasets.ImageFolder(
    os.path.join(data_dir, 'train_valid_test', folder),
    transform=transform_train) for folder in ['train', 'train_valid']]

valid_ds, test_ds = [torchvision.datasets.ImageFolder(
    os.path.join(data_dir, 'train_valid_test', folder),
    transform=transform_test) for folder in ['valid', 'test']]

# %%
train_iter, train_valid_iter = [torch.utils.data.DataLoader(
    dataset, batch_size, shuffle=True, drop_last=True)
    for dataset in (train_ds, train_valid_ds)]

valid_iter = torch.utils.data.DataLoader(valid_ds, batch_size, shuffle=False,
                                         drop_last=True)

test_iter = torch.utils.data.DataLoader(test_ds, batch_size, shuffle=False,
                                        drop_last=False)

# %% [markdown]
# ## Defining the [**Model**]

# %% [markdown]
# We define the ResNet-18 model described in
# :numref:`sec_resnet`.

# %%
def get_net():
    num_classes = 10
    net = d2l.resnet18(num_classes, 3)
    return net

loss = nn.CrossEntropyLoss(reduction="none")

# %% [markdown]
# ## Defining the [**Training Function**]
#
# We will select models and tune hyperparameters according to the model's performance on the validation set.
# In the following, we define the model training function `train`.

# %%
def train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period,
          lr_decay):
    trainer = torch.optim.SGD(net.parameters(), lr=lr, momentum=0.9,
                              weight_decay=wd)
    scheduler = torch.optim.lr_scheduler.StepLR(trainer, lr_period, lr_decay)
    num_batches, timer = len(train_iter), d2l.Timer()
    legend = ['train loss', 'train acc']
    if valid_iter is not None:
        legend.append('valid acc')
    animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
                            legend=legend)
    net = nn.DataParallel(net, device_ids=devices).to(devices[0])
    for epoch in range(num_epochs):
        net.train()
        metric = d2l.Accumulator(3)
        for i, (features, labels) in enumerate(train_iter):
            timer.start()
            l, acc = d2l.train_batch_ch13(net, features, labels,
                                          loss, trainer, devices)
            metric.add(l, acc, labels.shape[0])
            timer.stop()
            if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
                animator.add(epoch + (i + 1) / num_batches,
                             (metric[0] / metric[2], metric[1] / metric[2],
                              None))
        if valid_iter is not None:
            valid_acc = d2l.evaluate_accuracy_gpu(net, valid_iter)
            animator.add(epoch + 1, (None, None, valid_acc))
        scheduler.step()
    measures = (f'train loss {metric[0] / metric[2]:.3f}, '
                f'train acc {metric[1] / metric[2]:.3f}')
    if valid_iter is not None:
        measures += f', valid acc {valid_acc:.3f}'
    print(measures + f'\n{metric[2] * num_epochs / timer.sum():.1f}'
          f' examples/sec on {str(devices)}')

# %%
devices, num_epochs, lr, wd = d2l.try_all_gpus(), 2000, 2e-4, 5e-4
lr_period, lr_decay, net = 4, 0.9, get_net()
net(next(iter(train_iter))[0])
train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period,
      lr_decay)
# Out:
# c:\Users\nicka\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\nicka\Desktop\ΤΗΜΜΥ\7ο Εξάμηνο\Νευρωνικά Δίκτυα\1h_ergasia\MPL_CNN_NIKOLAOS_EVNGELIDIS_10571_2.ipynb Cell 27 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/nicka/Desktop/%CE%A4%CE%97%CE%9C%CE%9C%CE%A5/7%CE%BF%20%CE%95%CE%BE%CE%AC%CE%BC%CE%B7%CE%BD%CE%BF/%CE%9D%CE%B5%CF%85%CF%81%CF%89%CE%BD%CE%B9%CE%BA%CE%AC%20%CE%94%CE%AF%CE%BA%CF%84%CF%85%CE%B1/1h_ergasia/MPL_CNN_NIKOLAOS_EVNGELIDIS_10571_2.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> lr_period, lr_decay, net = 4, 0.9, get_net()
#       <a href='vscode-notebook-cell:/c%3A/Users/nicka/Desktop/%CE%A4%CE%97%CE%9C%CE%9C%CE%A5/7%CE%BF%20%CE%95%CE%BE%CE%AC%CE%BC%CE%B7%CE%BD%CE%BF/%CE%9D%CE%B5%CF%85%CF%81%CF%89%CE%BD%CE%B9%CE%BA%CE%AC%20%CE%94%CE%AF%CE%BA%CF%84%CF%85%CE%B1/1h_ergasia/MPL_CNN_NIKOLAOS_EVNGELIDIS_10571_2.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> net(next(iter(train_iter))[0])

# ---> <a href='vscode-notebook-cell:/c%3A/Users/nicka/Desktop/%CE%A4%CE%97%CE%9C%CE%9C%CE%A5/7%CE%BF%20%CE%95%CE%BE%CE%AC%CE%BC%CE%B7%CE%BD%CE%BF/%CE%9D%CE%B5%CF%85%CF%81%CF%89%CE%BD%CE%B9%CE%BA%CE%AC%20%CE%94%CE%AF%CE%BA%CF%84%CF%85%CE%B1/1h_ergasia/MPL_CNN_NIKOLAOS_EVNGELIDIS_10571_2.ipynb#X40sZmlsZQ%3D%3D?line=11'>12</a> net = nn.DataParallel(net, device_ids=devices).to(devices[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/nicka/Desktop/%CE%A4%CE%97%CE%9C%CE%9C%CE%A5/7%CE%BF%20%CE%95%CE%BE%CE%AC%CE%BC%CE%B7%CE%BD%CE%BF/%CE%9D%CE%B5%CF%85%CF%81%CF%89%CE%BD%CE%B9%CE%BA%CE%AC%20%CE%94%CE%AF%CE%BA%CF%84%CF%85%CE%B1/1h_ergasia/MPL_CNN_NIKOLAOS_EVNGELIDIS_10571_2.ipynb#X40sZmlsZQ%3D%3D?line=12'>13</a> for epoch in range(num_epochs):
#      <a href='vscode-notebook-cell:/c%3A/Users/nicka/Desktop/%CE%A4%CE%97%CE%9C%CE%9C%CE%A5/7%CE%BF%20%CE%95%CE%BE%CE%AC%CE%BC%CE%B7%CE%BD%CE%BF/%CE%9D%CE%B5%CF%85%CF%81%CF%89%CE%BD%CE%B9%CE%BA%CE%AC%20%CE%94%CE%AF%CE%BA%CF%84%CF%85%CE%B1/1h_ergasia/MPL_CNN_NIKOLAOS_EVNGELIDIS_10571_2.ipynb#X40sZmlsZQ%3D%3D?line=13'>14</a>     net.train()
#
# IndexError: list index out of range

# %% [markdown]
# ## [**Classifying the Testing Set**] and Submitting Results on Kaggle
#
# After obtaining a promising model with hyperparameters,
# we use all the labeled data (including the validation set) to retrain the model and classify the testing set.

# %%
net, preds = get_net(), []
net(next(iter(train_valid_iter))[0])
train(net, train_valid_iter, None, num_epochs, lr, wd, devices, lr_period,
      lr_decay)

for X, _ in test_iter:
    y_hat = net(X.to(devices[0]))
    preds.extend(y_hat.argmax(dim=1).type(torch.int32).cpu().numpy())
sorted_ids = list(range(1, len(test_ds) + 1))
sorted_ids.sort(key=lambda x: str(x))
df = pd.DataFrame({'id': sorted_ids, 'label': preds})
df['label'] = df['label'].apply(lambda x: train_valid_ds.classes[x])
df.to_csv('submission.csv', index=False)
# Out:
# train loss 0.608, train acc 0.786
# 1040.8 examples/sec on [device(type='cuda', index=0), device(type='cuda', index=1)]

# %% [markdown]
# Σε αυτό το σημείο είναι σαφές πως σε κάθε περίπτωση το καλύτερο είναι το τελευταίο μοντέλο, εφόσον χρησιμοποιεί αυξημένη πολυπλοκότητα, τηρώντας την αρχιτεκτονική των nested functions, αθξάνοντας την πολυπλοκότητα.

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/1479)
